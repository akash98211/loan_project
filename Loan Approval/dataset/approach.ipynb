# %%
1. Problem Statement 
2. data Gathering >> 


3. EDA
    >> Data Missing Value
    >> Correlataions 
    >> Outliers
    >> Data Types
    >> Data Distribution 
    >> Insights 
    >> Nature 
    >> Reports 
    >> Stats 
    >> Hypotethesis 
    
    
4. Feature Engg
    >> Imputation of missing value 
    >> categorical 
        >> label encoding 
        >> One hot encoding
    >> Scaling >> normalize >> scale down>>
        >> std (stdscaler)
        >> nor (minmaxscaler) >> 0 to 1 >> system resources require less
        >> log transform 
        >> cube trans
        >> sqrt transform 
    >> Outlier removal
    >> Imbalance to balance 
        >> Oversampling
        >> undersampling 
        >> SMOTE
        >> ensblening 
        >> SVMSMOTE
        >> KNNSMOTE
     
        
5. feature selection ::
    >> filter method 
        >> corrleation (person,spearman,kendell)
        >> chi square
        >> fisher score
        >> infomation gain 
        >> MAD(mean abs. dev)
        >> ANOVA
        >> missing value
        >> variance threshold
        >> dispersion ration 
        
    >> wrapper method
        >> forward selection 
        >> Backword elimination
        >> recursive feat. selection 
        >> Exhastive feat. selection 
        
    >> embedded methods 
        >> random forest
        >> L1 & L2
    
6. Model Building / Training 
    >> Regression 
        >> Linear 
        >> l1 & l2
        >> KNN reg
        >> Decision tree 
        >> Random forest 
        
    >> Classification
        >> Logistic >> train  
        >> DT
        >> KNN
        >> RF
        >> ensemble
            >> adaboost
7. Model Evaluate
    >>Regression
        >> MSE
        >> RMSE
        >> R2 Score
        >> Adj R2 score 
        >> MAE
    >> Classification 
        >> accuracy score 
        >> precision 
        >> recall 
        >> confusion matrix
        >> f(beta) score (f1 score) 
        >> AUC & ROC Curve
        >> clasification report 
        >> PR Curve
        



8. Deployment

# %%
Problem statement/ Business problem/ business requirement / what was the business scenario

What were the approaches:
Approach:
    regression
    classification
    TSA
    NLP

# %%
project duration(2 month -4months- 6 months -8 months) 8 months< maintetance/ development / recaliberation

# %%
how do we get project:
    POC(proof of concept) # >> test drive
    PPT/Deck, approach, duration >> client meet
    project assign >> 
    Main work 
    chetan.bangale@hdfcbank.in

# %%
Daily meet : Daily update
    eve
    morni
    afternoon 
    
    manager
    you
    senior
    junior
    project manager
    tech lead
    
client :
    weekly
    once in 2 week
    thursday 3 4 
    
    UK (-5hrs from IST)
    US (-13.30 hrs from IST)

# %%
Data requiremnet:
    what kind of features u need ?
    pizza:
        1. sales report
        2. location 
        3. population
        4. outltes
        5. peak time
        6. types veg-non
        7. discount
        8. home delivery
        9. customer review

# %%
how do u receive your data?
1) client DB (SQL server) VDE (virtual desktop environment) VPN setup location link / drive access
2) Data Engineer (DB) mail
3) third party API
4) Web Scraping
5) cloud storage

# %%
teamviewer
anydesk

# %%
how is work assigned to u / project managemnet tool?
Jeera, zoho, trello, asana

# %%
>> how frequently your data was being updated
100000 rows >> 35 colm
120000 rows >> 38 colm 
129000 rows >> 42 colm
>> how frequent was your meeting with client
>> what was your role in client meet

# %%
>> who was there in your team:
    data scientist/ml engineer 2-4
    data engineer 1-2
    Business analyst 1
    Project manager 1
    Powerbi engineer 1-2 
    
    front end
    backend

# %%
isstray true,false
age 0-5 5-10 10-15

# %%
age

# %%
df is ready 

convert/ resample weekly /monthly

# %%
plot

# %%
evaluation metrics:
    MAPE
    RMSPE

# %%
Deploy:
    online:
        AWS
        GCP
        Azure
        
    offline:
        predicted ouput in table format >> save in csv and then fetch it on SQL server

# %%
Databricks = cloud platform 
online platform for coding and data storage

DBFS (Databricks file system)

# %%
TSA

what freq u predicted >> weekly , monthly, daily
how to check stationarity >> 
how to achieve stationarity >> 
which models have u used >> 
seasonal factor >> sarima, fbprophet
how do deploy model
what was the approach >>
